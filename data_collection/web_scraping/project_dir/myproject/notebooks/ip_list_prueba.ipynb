# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
url = 'https://free-proxy-list.net/'

# %%
soup = bs(requests.get(url).content, 'html5lib')
soup  #'html.parser'
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.find('table', attrs={'class': 'table table-striped table-bordered'}))
# Out:
# <table class="table table-striped table-bordered"><thead><tr><th>IP Address</th><th>Port</th><th>Code</th><th class="hm">Country</th><th>Anonymity</th><th class="hm">Google</th><th class="hx">Https</th><th class="hm">Last Checked</th></tr></thead><tbody><tr><td>188.227.186.102</td><td>443</td><td>GB</td><td class="hm">United Kingdom</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">22 secs ago</td></tr><tr><td>197.157.219.169</td><td>48625</td><td>NG</td><td class="hm">Nigeria</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">22 secs ago</td></tr><tr><td>168.228.150.5</td><td>47507</td><td>BR</td><td class="hm">Brazil</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">22 secs ago</td></tr><tr><td>217.219.61.6</td><td>8080</td><td>IR</td><td class="hm">Iran</td><td>anonymous</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">22 secs ago</td></tr><tr><td>150.129.148.88</td>
# ...

# %%
soup.find('table', attrs={'class': 'table table-striped table-bordered'}).find_all('tr')[1:]
# Out:
# [<tr><td>188.227.186.102</td><td>443</td><td>GB</td><td class="hm">United Kingdom</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">22 secs ago</td></tr>,
#  <tr><td>197.157.219.169</td><td>48625</td><td>NG</td><td class="hm">Nigeria</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">22 secs ago</td></tr>,
#  <tr><td>168.228.150.5</td><td>47507</td><td>BR</td><td class="hm">Brazil</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">22 secs ago</td></tr>,
#  <tr><td>217.219.61.6</td><td>8080</td><td>IR</td><td class="hm">Iran</td><td>anonymous</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">22 secs ago</td></tr>,
#  <tr><td>150.129.148.88</td><td>35101</td><td>IN</td><td class="hm">India</td><td>elite proxy</td><td class="hm">no</td><td class="hx">yes</td><td class="hm">22 secs ago</td></tr>,
# ...

# %%
for row in soup.find('table', attrs={'class': 'table table-striped table-bordered'}).find_all('tr')[1:]:
        print(row.find_all('td'))
# Out:
# [<td>188.227.186.102</td>, <td>443</td>, <td>GB</td>, <td class="hm">United Kingdom</td>, <td>elite proxy</td>, <td class="hm">no</td>, <td class="hx">yes</td>, <td class="hm">22 secs ago</td>]
# [<td>197.157.219.169</td>, <td>48625</td>, <td>NG</td>, <td class="hm">Nigeria</td>, <td>elite proxy</td>, <td class="hm">no</td>, <td class="hx">yes</td>, <td class="hm">22 secs ago</td>]
# [<td>168.228.150.5</td>, <td>47507</td>, <td>BR</td>, <td class="hm">Brazil</td>, <td>elite proxy</td>, <td class="hm">no</td>, <td class="hx">yes</td>, <td class="hm">22 secs ago</td>]
# [<td>217.219.61.6</td>, <td>8080</td>, <td>IR</td>, <td class="hm">Iran</td>, <td>anonymous</td>, <td class="hm">no</td>, <td class="hx">yes</td>, <td class="hm">22 secs ago</td>]
# [<td>150.129.148.88</td>, <td>35101</td>, <td>IN</td>, <td class="hm">India</td>, <td>elite proxy</td>, <td class="hm">no</td>, <td class="hx">yes</td>, <td class="hm">22 secs ago</td>]
# ...
